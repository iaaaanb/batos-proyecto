# %%
import pandas as pd

persona = pd.read_csv("./../tablas/persona_limpia.csv")
hogar = pd.read_csv("./../tablas/hogar.csv")

# %%
print("persona:", persona.shape[0])
print("hogar:", hogar.shape[0])
# Out:
# persona: 218367
# hogar: 78654
